# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as matDates

# %% [markdown]
# step - 2)	Read the daily confirmed cases and deaths into two dataframes can be found at this github page: a)	confirmed_cases_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
# b)	deaths_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"

# %%
dataFrame_confirm_cases_2019 = pd.read_csv ('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
dataFrame_death_cases_2019 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
#These are the confirmed cases of covid 2019
dataFrame_confirm_cases_2019
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/25/22  11/26/22  \
# ...

# %%
dataFrame_death_cases_2019
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/25/22  11/26/22  \
# ...

# %% [markdown]
# SUM OF TOTAL CONFIRM CASES Of COVID_19:

# %%
dataFrame_confirm_cases_2019['Total_Confirmed_Cases'] = dataFrame_confirm_cases_2019.iloc[:,4:].sum(axis=1)
dataFrame_confirm_cases_2019
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/26/22  11/27/22  \
# ...

# %%
dataFrame_death_cases_2019['Total_Death_Cases'] = dataFrame_death_cases_2019.iloc[:,4:].sum(axis=1)

dataFrame_death_cases_2019
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/26/22  11/27/22  \
# ...

# %% [markdown]
# step -3) -	Use pandas to create a dataframe that aggregates and sums both confirmed cases and deaths on a global level

# %%
cases_2019 = dataFrame_confirm_cases_2019[['Province/State','Country/Region','Total_Confirmed_Cases']]

death_2019 = dataFrame_death_cases_2019[['Province/State','Country/Region','Total_Death_Cases']]

# %% [markdown]
# TOTAL CASES AND DEATH ON GLOBAL LEVEL:

# %%
globalLevelData = pd.merge(cases_2019, death_2019, on=['Province/State','Country/Region'])
globalLevelData
# Out:
#     Province/State        Country/Region  Total_Confirmed_Cases  \
# 0              NaN           Afghanistan              110214917
# 1              NaN               Albania              153830108
# 2              NaN               Algeria              156966802
# 3              NaN               Andorra               20010202
# 4              NaN                Angola               50040541
# ..             ...                   ...                    ...
# 284            NaN    West Bank and Gaza              345738380
# 285            NaN  Winter Olympics 2022                 163637
# 286            NaN                 Yemen                6744660
# 287            NaN                Zambia              163803740
# 288            NaN              Zimbabwe              115554724
#
#      Total_Death_Cases
# 0              4673864
# 1              2143775
# 2              4247580
# 3               111622
# 4              1048488
# ..                 ...
# 284            3212449
# ...

# %% [markdown]
# 5) Use AlphaVantage Key to get the DAILY HIGH and LOW prices for your selected stocks.

# %%
acc_key = 'V6ADDIBOGX34JYRJ.'

# %% [markdown]
# Stock selection

# %%
pip install alpha-vantage
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key=acc_key,output_format='pandas')
A_american = ts.get_daily_adjusted('NASDX')
C_canadian = ts.get_daily_adjusted('TSE')
T_travel = ts.get_daily_adjusted('DAL') 
D_real_estate = ts.get_daily_adjusted('ALEX')
P_precious_metals = ts.get_daily_adjusted('GOLD')

# %% [markdown]
# create a dataframe for stocks.

# %%
df_american = pd.DataFrame(A_american[0]).reset_index(level=0)
df_canadian = pd.DataFrame(C_canadian[0]).reset_index(level=0)
df_travel = pd.DataFrame(T_travel[0]).reset_index(level=0)
df_real_estate = pd.DataFrame(D_real_estate[0]).reset_index(level=0)
df_precious_metals = pd.DataFrame(P_precious_metals[0]).reset_index(level=0)
df_american
df_canadian
df_travel
df_real_estate
df_precious_metals
# Out:
#          date  1. open  2. high  3. low  4. close  5. adjusted close  \
# 0  2022-12-05    16.81  16.9092   16.47     16.52          16.520000
# 1  2022-12-02    16.78  17.1400   16.58     16.98          16.980000
# 2  2022-12-01    16.75  17.3400   16.67     17.09          17.090000
# 3  2022-11-30    16.03  16.4400   15.87     16.32          16.320000
# 4  2022-11-29    15.59  15.9600   15.54     15.87          15.870000
# ..        ...      ...      ...     ...       ...                ...
# 95 2022-07-21    15.52  15.7600   15.38     15.50          15.348925
# 96 2022-07-20    15.99  16.0450   15.43     15.45          15.299412
# 97 2022-07-19    15.83  16.0800   15.71     16.03          15.873759
# 98 2022-07-18    15.96  16.0860   15.82     15.82          15.665806
# 99 2022-07-15    15.86  15.8800   15.40     15.66          15.507365
#
#      6. volume  7. dividend amount  8. split coefficient
# 0   21242900.0                0.00                   1.0
# ...

# %% [markdown]
# CHANGE COLUMN NAME AS PER REQUIREMRNT [DATE, HIGH, LOW]:

# %%
df_american = df_american[['date','2. high','3. low']].rename(columns={"2. high":"american_high","3. low":"american_low"})
df_canadian = df_canadian[['date','2. high','3. low']].rename(columns={"2. high":"canadian_high","3. low":"canadian_low"})
df_travel = df_travel[['date','2. high','3. low']].rename(columns={"2. high":"travel_high","3. low":"travel_low"})
df_real_estate = df_real_estate[['date','2. high','3. low']].rename(columns={"2. high":"real_estate_high","3. low":"real_estate_low"})
df_precious_metals = df_precious_metals[['date','2. high','3. low']].rename(columns={"2. high":"metal_high","3. low":"metal_low"})

# %% [markdown]
# Merge stocks on Date

# %%
stocks = df_american.merge(df_canadian, on="date").merge(df_precious_metals, on="date").merge(df_real_estate,on="date").merge(df_travel,on="date")
stocks
# Out:
#          date  american_high  american_low  canadian_high  canadian_low  \
# 0  2022-12-02          25.90         25.90         24.845        24.100
# 1  2022-12-01          26.01         26.01         25.440        24.520
# 2  2022-11-30          25.97         25.97         24.700        23.390
# 3  2022-11-29          25.57         25.57         24.390        23.605
# 4  2022-11-28          25.75         25.75         24.140        23.230
# ..        ...            ...           ...            ...           ...
# 94 2022-07-21          28.02         28.02         43.160        41.740
# 95 2022-07-20          27.63         27.63         43.760        42.680
# 96 2022-07-19          27.20         27.20         43.990        41.909
# 97 2022-07-18          26.38         26.38         42.990        41.270
# 98 2022-07-15          26.62         26.62         40.520        39.300
#
#     metal_high  metal_low  real_estate_high  real_estate_low  travel_high  \
# ...

# %% [markdown]
# GroupBy Country/Region

# %%
dataFrame_Canada_Death_Cases = dataFrame_death_cases_2019[dataFrame_death_cases_2019['Country/Region'] == "Canada"].groupby("Country/Region").sum()
dataFrame_US_Death_Cases =dataFrame_death_cases_2019[dataFrame_death_cases_2019['Country/Region'] == "US"].groupby("Country/Region").sum()

dataFrame_Canada_Confirmed_Cases = dataFrame_confirm_cases_2019[dataFrame_confirm_cases_2019['Country/Region'] == "Canada"].groupby("Country/Region").sum()
dataFrame_US_Confirmed_Cases =dataFrame_confirm_cases_2019[dataFrame_confirm_cases_2019['Country/Region'] == "US"].groupby("Country/Region").sum()

# %% [markdown]
# Drop colums of Lat and Long

# %%
canadaDeathCase = dataFrame_Canada_Death_Cases.reset_index().drop(columns=["Lat","Long"]).transpose().reset_index()

canadaDeathCase.columns = ["date","Canada_Death_Cases"]
canadaDeathCase = canadaDeathCase.iloc[1:-1]

USDeathCase = dataFrame_US_Death_Cases.reset_index().drop(columns=["Lat","Long"]).transpose().reset_index()

USDeathCase.columns = ["date","US_Death_Cases"]
USDeathCase = USDeathCase.iloc[1:-1]

canadaConfirmedCase = dataFrame_Canada_Confirmed_Cases.reset_index().drop(columns=["Lat","Long"]).transpose().reset_index()

canadaConfirmedCase.columns = ["date","Canada_Confirmed_Cases"]
canadaConfirmedCase = canadaConfirmedCase.iloc[1:-1]

USConfirmedCase = dataFrame_US_Confirmed_Cases.reset_index().drop(columns=["Lat","Long"]).transpose().reset_index()

USConfirmedCase.columns = ["date","US_Confirmed_Cases"]
USConfirmedCase = USConfirmedCase.iloc[1:-1]

# %% [markdown]
# Death and Confirmed Cases on Date

# %%
death = canadaDeathCase.merge(USDeathCase, on="date")
confirm = canadaConfirmedCase.merge(USConfirmedCase, on="date")

final = death.merge(confirm, on = "date")

# %% [markdown]
# Final Merged DataFrame of Corona Cases and Stock Market data

# %%
final['date'] = pd.to_datetime(final['date'])

final = final.merge(stocks, on='date',how='left')
final
# Out:
#            date Canada_Death_Cases US_Death_Cases Canada_Confirmed_Cases  \
# 0    2020-01-22                  0              0                      0
# 1    2020-01-23                  0              0                      2
# 2    2020-01-24                  0              0                      3
# 3    2020-01-25                  0              0                      3
# 4    2020-01-26                  0              0                      3
# ...         ...                ...            ...                    ...
# 1043 2022-11-30              48002        1080536                4432426
# 1044 2022-12-01              48133        1081147                4444843
# 1045 2022-12-02              48133        1081412                4444912
# 1046 2022-12-03              48133        1081431                4444912
# 1047 2022-12-04              48133        1081431                4444912
#
#      US_Confirmed_Cases  american_high  american_low  canadian_high  \
# ...

# %%
fig = plt.figure()

plt.plot_date(final['date'],final['Canada_Death_Cases'],'b-')

plt.title("Canada Death list")
plt.xlabel("Year and Months")
plt.ylabel("Death Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()
plt.plot_date(final['date'],final['US_Death_Cases'],'b-')

plt.title("US Death list")
plt.xlabel("Year and Months")
plt.ylabel("Death Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()
plt.plot_date(final['date'],final['Canada_Death_Cases'],'b-')
plt.plot_date(final['date'],final['US_Death_Cases'],'g-')

plt.title("US - Canada Death Ratio")
plt.xlabel("Year and Months")
plt.ylabel("Death Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()
plt.plot_date(final['date'],final['Canada_Confirmed_Cases'],'b-')

plt.title("Canada Confirmed Cases Throughut time")
plt.xlabel("Year and Months")
plt.ylabel("Confirmed Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()
plt.plot_date(final['date'],final['US_Confirmed_Cases'],'b-')

plt.title("US Confirmed Cases Throughout Time")
plt.xlabel("Year and Months")
plt.ylabel("Confirmed Cases Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()
plt.plot_date(final['date'],final['Canada_Confirmed_Cases'],'b-')
plt.plot_date(final['date'],final['US_Confirmed_Cases'],'g-')

plt.title("US - Canada Confirmed cases Ratio")
plt.xlabel("Year and Months")
plt.ylabel("Confirmed Cases Count")

fig.autofmt_xdate()
plt.show()

# %%
fig = plt.figure()

plt.plot_date(stocks['date'],stocks['american_high'],'g-')
plt.plot_date(stocks['date'],stocks['american_low'],'r-')

plt.title("Overall stock Market of USA")
plt.xlabel("Year and Months")
plt.ylabel("Value")

plt.show()

# %%
fig = plt.figure()
plt.plot_date(stocks['date'],stocks['canadian_high'],'g-')
plt.plot_date(stocks['date'],stocks['canadian_low'],'r-')

plt.title("Overall stock Market of canada")
plt.xlabel("Year and Months")
plt.ylabel("Value")

plt.show()

# %%
fig = plt.figure()
plt.plot_date(stocks['date'],stocks['metal_high'],'g-')
plt.plot_date(stocks['date'],stocks['metal_high'],'r-')

plt.title("Overall gold market Throughout Time")
plt.xlabel("Year and Months")
plt.ylabel("Value")

plt.show()
